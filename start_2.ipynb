# %%
# Dependencies
import requests
import json
from config import api_key
from pprint import pprint

# %%
# URL for GET requests to retrieve vehicle data
# Note that the ?t= is a query param for the t-itle of the
# movie we want to search for.
url = "https://quiniwine.com/api/pub/wineKeywordSearch/rose"
api_key = "&apikey=fYeSO-ChogAFnqAvDHv1"

# %%
# Print the response object to the console
print(url + api_key)
response = requests.get(url)

print(requests.get(url))
# Out:
# https://quiniwine.com/api/pub/wineKeywordSearch/rose&apikey=fYeSO-ChogAFnqAvDHv1
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
data = response.json()
pprint(data)
# Out:
# {'category': 'All',
#  'items': [{'Area': 'Victoria',
#             'Country': 'Australia',
#             'Name': 'Tar & Roses',
#             'Province': '',
#             'Style': '',
#             'Type': 'Red',
#             'Varietal': 'Nebbiolo',
#             'Winery': 'Tar & Roses',
#             '_id': '55585e69827e050300000007',
#             'id': '55585e69827e050300000007',
#             'vintage': '2006'},
#            {'Area': 'Monticello',
#             'Country': 'USA',
#             'Name': 'Crose',
#             'Province': 'Virginia',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': 'Merlot',
#             'Winery': 'King Family Vineyards',
#             '_id': '535975d9682acc02000074bb',
#             'id': '535975d9682acc02000074bb',
#             'vintage': 'nv'},
#            {'Area': 'Loire Valley',
#             'Country': 'France',
#             'Name': 'Chinon Rosė',
#             'Province': '',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': 'Cabernet Franc',
#             'Winery': 'Domaine Dozon',
#             '_id': '55a28134174e540300000014',
#             'id': '55a28134174e540300000014',
#             'vintage': '2014'},
#            {'Area': 'Okanagan Valley',
#             'Country': 'Canada',
#             'Name': 'Monster Rosie Sparkling 2017',
#             'Province': '',
#             'Style': 'Sparkling',
#             'Type': 'Rose',
#             'Varietal': 'Rose Blend',
#             'Winery': 'Monster Vineyards',
#             '_id': '5cd1f3f068580d752dd58758',
#             'id': '5cd1f3f068580d752dd58758',
#             'vintage': '2017'},
#            {'Area': 'Piedmont',
#             'Country': 'Italy',
#             'Name': 'Cuvage Rise Brut',
#             'Province': '',
#             'Style': 'Sparkling',
#             'Type': 'Rose',
#             'Varietal': 'Nebbiolo',
#             'Winery': 'Cuvage',
#             '_id': '58cec814d69ba3b478df074e',
#             'id': '58cec814d69ba3b478df074e',
#             'vintage': 'nv'},
#            {'Area': 'Ohio River Valley',
#             'Country': 'USA',
#             'Name': 'Rosy Future',
#             'Province': 'Kentucky',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': '',
#             'Winery': 'Broad Run Vineyards',
#             '_id': '535973d0682acc0200000359',
#             'id': '535973d0682acc0200000359',
#             'vintage': 'nv'},
#            {'Area': '',
#             'Country': 'USA',
#             'Name': 'Rosey Ass',
#             'Province': 'Iowa',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': '',
#             'Winery': 'Bel-Aire Estates Winery',
#             '_id': '535a5f7a7dd3dc02000000b0',
#             'id': '535a5f7a7dd3dc02000000b0',
#             'vintage': 'nv'},
#            {'Area': 'Vin De France',
#             'Country': 'France',
#             'Name': 'Petit Cochon Bronzè Rosè',
#             'Province': '',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': 'Cinsault, Syrah',
#             'Winery': 'Domaine Rimbert',
#             '_id': '56b0f490cb9d45030060cda1',
#             'id': '56b0f490cb9d45030060cda1',
#             'vintage': 'nv'},
#            {'Area': 'Veneto',
#             'Country': 'Italy',
#             'Name': 'Valdo Origine Rosè, Spumante Brut',
#             'Province': '',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': 'Red blend',
#             'Winery': 'Valdo',
#             '_id': '554250f1eb915703000026ed',
#             'id': '554250f1eb915703000026ed',
#             'vintage': 'nv'},
#            {'Area': 'Marche',
#             'Country': 'Italy',
#             'Name': 'Roseo',
#             'Province': '',
#             'Style': '',
#             'Type': 'Rose',
#             'Varietal': 'Sangiovese, Montepulciano',
#             'Winery': 'Boccadigabbia',
#             '_id': '554250eceb91570300001852',
#             'id': '554250eceb91570300001852',
#             'vintage': 'nv'}],
#  'nextskip': 10}

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "category": "All",
#     "items": [
#         {
#             "Area": "Victoria",
#             "Country": "Australia",
#             "Name": "Tar & Roses",
#             "Province": "",
#             "Style": "",
#             "Type": "Red",
#             "Varietal": "Nebbiolo",
#             "Winery": "Tar & Roses",
#             "_id": "55585e69827e050300000007",
#             "id": "55585e69827e050300000007",
#             "vintage": "2006"
#         },
#         {
#             "Area": "Monticello",
#             "Country": "USA",
#             "Name": "Crose",
#             "Province": "Virginia",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "Merlot",
#             "Winery": "King Family Vineyards",
#             "_id": "535975d9682acc02000074bb",
#             "id": "535975d9682acc02000074bb",
#             "vintage": "nv"
#         },
#         {
#             "Area": "Loire Valley",
#             "Country": "France",
#             "Name": "Chinon Ros\u0117",
#             "Province": "",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "Cabernet Franc",
#             "Winery": "Domaine Dozon",
#             "_id": "55a28134174e540300000014",
#             "id": "55a28134174e540300000014",
#             "vintage": "2014"
#         },
#         {
#             "Area": "Okanagan Valley",
#             "Country": "Canada",
#             "Name": "Monster Rosie Sparkling 2017",
#             "Province": "",
#             "Style": "Sparkling",
#             "Type": "Rose",
#             "Varietal": "Rose Blend",
#             "Winery": "Monster Vineyards",
#             "_id": "5cd1f3f068580d752dd58758",
#             "id": "5cd1f3f068580d752dd58758",
#             "vintage": "2017"
#         },
#         {
#             "Area": "Piedmont",
#             "Country": "Italy",
#             "Name": "Cuvage Rise Brut",
#             "Province": "",
#             "Style": "Sparkling",
#             "Type": "Rose",
#             "Varietal": "Nebbiolo",
#             "Winery": "Cuvage",
#             "_id": "58cec814d69ba3b478df074e",
#             "id": "58cec814d69ba3b478df074e",
#             "vintage": "nv"
#         },
#         {
#             "Area": "Ohio River Valley",
#             "Country": "USA",
#             "Name": "Rosy Future",
#             "Province": "Kentucky",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "",
#             "Winery": "Broad Run Vineyards",
#             "_id": "535973d0682acc0200000359",
#             "id": "535973d0682acc0200000359",
#             "vintage": "nv"
#         },
#         {
#             "Area": "",
#             "Country": "USA",
#             "Name": "Rosey Ass",
#             "Province": "Iowa",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "",
#             "Winery": "Bel-Aire Estates Winery",
#             "_id": "535a5f7a7dd3dc02000000b0",
#             "id": "535a5f7a7dd3dc02000000b0",
#             "vintage": "nv"
#         },
#         {
#             "Area": "Vin De France",
#             "Country": "France",
#             "Name": "Petit Cochon Bronz\u00e8 Ros\u00e8",
#             "Province": "",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "Cinsault, Syrah",
#             "Winery": "Domaine Rimbert",
#             "_id": "56b0f490cb9d45030060cda1",
#             "id": "56b0f490cb9d45030060cda1",
#             "vintage": "nv"
#         },
#         {
#             "Area": "Veneto",
#             "Country": "Italy",
#             "Name": "Valdo Origine Ros\u00e8, Spumante Brut",
#             "Province": "",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "Red blend",
#             "Winery": "Valdo",
#             "_id": "554250f1eb915703000026ed",
#             "id": "554250f1eb915703000026ed",
#             "vintage": "nv"
#         },
#         {
#             "Area": "Marche",
#             "Country": "Italy",
#             "Name": "Roseo",
#             "Province": "",
#             "Style": "",
#             "Type": "Rose",
#             "Varietal": "Sangiovese, Montepulciano",
#             "Winery": "Boccadigabbia",
#             "_id": "554250eceb91570300001852",
#             "id": "554250eceb91570300001852",
#             "vintage": "nv"
#         }
#     ],
#     "nextskip": 10
# }
